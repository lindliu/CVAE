# %% [markdown]
# # Conditional Variational Autoencoder(CVAE) for Anomaly Detection
# Donglin Liu <br>
# Jupyter-course project

# %% [markdown]
# # Introduction

# %% [markdown]
# The project will first give a general introduction to variational autoencoder(VAE), then the conditional variational autoencoder(CVAE) will be discussed. This proposed conditional variational autonencoder improves latent space separation by conditioning on information within the data. The method fits a unique prior distribution to each class in the dataset, effectively expanding the classic prior distribution for variational autoenconders to include a Gaussian mixture model. Such probability regions in latent space can help us to evaluate their degree of anomaly.
#
# The experiments is implemented by Tensorflow 2.X using Keras API on MINST dataset. And all the results has saved in text files, no need to train the model again.
# The idea of this work is mainly based on the paper [[1]](#refer-anchor-1),[[4]](#refer-anchor-4). The code is inspired by project [[2]](#refer-anchor-2),[[3]](#refer-anchor-3).

# %% [markdown]
# # VAE

# %% [markdown]
# For many machine learning algorithm, the size of dataset always play an important role. But data collection can be expensive, time consuming and difficult. The ideal condition is we know the distribution of the dataset $p_\theta(x)$, so that we can easily to generate new data by the distribution. VAE is try to solve this problem.
#
# Usually, data from real world have unknown distribution in high dimensional space. So we can construct a latent variable $z$ to generate target dataset $X$ which is the basic goal of VAE. To be more precise, $z$ is generated from some prior distribution $p_\theta(z)$ which hypothetical by some common distribution (such as normal distribution or uniform distribution). Then we want to find a transformation $g$ from likelihood $p_\theta(x|z)$ such that $X=g(z)$. The transformation $g$ maps the original probability distribution of $z$ to the probability distribution of the target dataset $X$.
#
# We know the integral of the marginal likelihood $p_\theta(x) = \int p_\theta(z)p_\theta(x|z)dz$ is intractable. The posterior density $p_\theta(z|x) = \frac{p_\theta(x|z)p_\theta(z)}{p_\theta(x)}$ is also intractable. But $p_\theta(z|x)$ can be considered using $q_\phi(z|x)$ to approximate. We will refer to $q_\phi(z|x)$ as a probabilistic encoder and $p_\theta(x|z)$ as a probabilistic decoder.
#
# For the purpose of solving $p_\theta(x)$, we now just need a method for learning the encoder parameters $\phi$ and decoder parameters $\theta$ if we just consider these two models are two neural networks.

# %% [markdown]
# \begin{eqnarray*}
# logp_\theta(x) &=& E_{z\sim q_{\phi(z|x)}}[logp_{\theta}(x)] \qquad\text{By p(x) not depend on z}\\
#                &=& E_{z}[log\frac{p_{\theta}(x|z)p(z)}{p_{\theta}(z|x)}] \qquad\text{By bayer's rule}\\
#                &=& E_z[log\frac{p_{\theta}(x|z)p_{\theta}(z)}{p_{\theta}(z|x)}\frac{q_{\phi}(z|x)}{q_{\phi}(z|x)}]\\
#                &=& E_z[logp_\theta(x|z)]-E_z[log\frac{q_\phi(z|x)}{p_\theta(z)}]+E_z[log\frac{q_\phi(z|x)}{p_\theta(z|x)}]\\
#                &=& \underbrace{E_z[logp_\theta(x|z)]-D_{KL}(q_\phi(z|x)\|p_\theta(z))}_{\text{tractable lower bound $\mathcal{L}(\theta,\phi;x)$}}+\underbrace{D_{KL}(q_\phi(z|x)\|p_\theta(z|x))}_{\text{intractable, but $D_{KL}\ge 0$}}
# \end{eqnarray*}

# %% [markdown]
# The lower bound of $logx_\theta(x)$ is shown above to be,
# $$\mathcal{L}(\theta,\phi;x)=E_{z\sim q_{\phi}(z|x)}[logp_\theta(x|z)]-D_{KL}(q_\phi(z|x)\|p_\theta(z))$$
# The task is to maximize the $\mathcal{L}$ with respect to the parameters $\theta$ and $\phi$,
# $$\phi^{\ast},\theta^{\ast}=\mathop{\arg\max}_{\phi,\theta}\mathcal{L}(\theta,\phi;x)$$

# %% [markdown]
# Let the prior over the latent variables be the centered isotropic multivariate Gaussian $p_\theta(z) = \mathcal{N}(z;0,I)$.
# We also assume the approximate posterior $q_\phi(z|x)$ in Gaussian form with an approximately diagonal covariance
# $$logq_\phi(z|x^{(i)})=log\mathcal{N}(z;\mu^{(i)},\sigma^{2(i)}I)$$
# The $D_{KL}$ term in $\mathcal{L}$ can be derive as follows:
# \begin{eqnarray*}
# D_{KL}(q_\phi(z|x)\|p_\theta(z)) &=& E_{z\sim q_\phi(z|x)}[logq_\phi(z|x)]-E_{z\sim q_\phi(z|x)}[logp_\theta(z)]\\
#    &=& E_z[log\frac{1}{(2\pi)^{d/2}|\Sigma|^{1/2}}exp(-\frac{1}{2}(x-\mu)^T\Sigma^{-1}(x-\mu))]-E_z[log\frac{1}{(2\pi)^{1/2}|\Sigma|^{1/2}}exp(-\frac{1}{2}\|x\|^2)]\\
#    &=& -\frac{d}{2}log(2\pi)-\frac{1}{2}log\mathop{\Pi}_{i=1}^{d}\sigma_{i}^{2}-\underbrace{E_z[exp(-\frac{1}{2}(x-\mu)^T\Sigma^{-1}(x-\mu))]}_{=-\frac{d}{2}}+-\frac{d}{2}log(2\pi)+\frac{1}{2}\mathop{\sum}_{i=1}^{d}(\mu_{i}^2+\sigma_{i}^2)\\
#    &=& -\frac{1}{2}\mathop{\sum}_{i=1}^{d}(1+log(\sigma_i^2)-\mu_i^2-\sigma_i^2)
# \end{eqnarray*}
# So $\mathcal{L}(\theta,\phi;x)=\frac{1}{2}\mathop{\sum}_{i=1}^{d}(1+log(\sigma_i^2)-\mu_i^2-\sigma_i^2)+\frac{1}{L}\mathop{\sum}_{l=1}^{L}logp_\theta(x|z^{l})$,
# where $z^l=\mu+\sigma\odot\epsilon^l$ and $\epsilon^l\sim \mathcal{N}(0,I)$.
# Here $\epsilon$ is for sampling $z^l$ called reparameterization trick.

# %% [markdown]
# ### Build the VAE model

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import pandas as pd
from sklearn.neighbors import LocalOutlierFactor

import tensorflow as tf
from tensorflow.keras import backend as K

from tensorflow.keras.layers import Input, Dense, Lambda, Layer, Add, Multiply
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
# %conda env export > requirements.yml
# Out:
# 2022-06-13 12:15:25.627296: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %% [markdown]
# In this example code, for encoder, we assume $q_\phi(z|x^{(i)})=\mathcal{N}(z;\mu^{(i)},\sigma^{2(i)}I)$ and specify the mean $\mu_\phi(x)$ and log variance $log\sigma_\phi^2(x)$ of this distribution as the output of an inference network.

# %%
original_dim, intermediate_dim, latent_dim = 784, 256, 2

x = Input(shape=(original_dim,))
h = Dense(intermediate_dim, activation='relu')(x)

z_mu = Dense(latent_dim)(h)
z_log_var = Dense(latent_dim)(h)

encoder = Model(x, z_mu)
# Out:
# 2022-06-13 12:15:27.079091: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2022-06-13 12:15:27.103031: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-13 12:15:27.103216: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 3060 Laptop GPU computeCapability: 8.6
# coreClock: 1.425GHz coreCount: 30 deviceMemorySize: 5.80GiB deviceMemoryBandwidth: 312.97GiB/s
# 2022-06-13 12:15:27.103293: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2022-06-13 12:15:27.123174: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2022-06-13 12:15:27.123301: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2022-06-13 12:15:27.144732: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2022-06-13 12:15:27.147068: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2022-06-13 12:15:27.150072: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2022-06-13 12:15:27.155905: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2022-06-13 12:15:27.156396: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.2/lib64
# 2022-06-13 12:15:27.156425: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-06-13 12:15:27.157191: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-13 12:15:27.158695: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-06-13 12:15:27.158721: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]

# %% [markdown]
# Now we sampling in probability space of $z$ by reparameterization trick.

# %%
def sampling(args):
    z_mu, z_log_var = args
    epsilon = K.random_normal(shape=(K.shape(z_mu)[0], latent_dim)) #default mean=0, stddev=1
    return z_mu + K.exp(.5*z_log_var) * epsilon

z = Lambda(sampling, output_shape=(latent_dim,))([z_mu, z_log_var]) # sampling

# %% [markdown]
# For $p_\theta(x|z)$ the decoder part, it is straightforward to implement this in Keras with the Sequential model API:

# %%
decoder = Sequential([
    Dense(intermediate_dim, input_dim=latent_dim, activation='relu'),
    Dense(original_dim, activation='sigmoid')
])

x_recon = decoder(z)
vae = Model(inputs=x, outputs=x_recon)

# %% [markdown]
# The loss function is just $-\mathcal{L}(\theta,\phi;x)$ as we discussed above

# %%
#keras.losses.binary_crossentropy gives the mean over the last axis. we require the sum
xent_loss = K.sum(K.binary_crossentropy(x, x_recon), axis=-1) 
kl_loss = K.mean(- .5 * K.sum(1 + z_log_var - K.square(z_mu) - K.exp(z_log_var), axis=-1))
vae_loss = xent_loss + kl_loss

vae.add_loss(vae_loss)
vae.compile(optimizer='rmsprop')#, loss=nll)

# %% [markdown]
# The $\mu$ for test dataset in latent space has been saved in text file. If you want to repeat it, you can run the following code.

# %%
# train the VAE on MNIST digits
(x_train, Y_train), (x_test, Y_test) = mnist.load_data()
x_train = x_train.reshape(-1, original_dim) / 255.
x_test = x_test.reshape(-1, original_dim) / 255.

vae.fit(x_train,
        x_train,
        shuffle=True,
        epochs=50,
        batch_size=64,
        validation_data=(x_test, x_test))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 5s 0us/step
# 2022-06-13 12:15:43.528931: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-06-13 12:15:43.547787: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 3194070000 Hz
# Epoch 1/50
# 938/938 [==============================] - 5s 5ms/step - loss: 185.9391 - val_loss: 170.9673
# Epoch 2/50
# 938/938 [==============================] - 5s 5ms/step - loss: 168.7590 - val_loss: 165.8243
# Epoch 3/50
# 938/938 [==============================] - 4s 5ms/step - loss: 164.4004 - val_loss: 162.6502
# Epoch 4/50
# 938/938 [==============================] - 5s 5ms/step - loss: 161.8446 - val_loss: 160.6538
# Epoch 5/50
# 938/938 [==============================] - 5s 5ms/step - loss: 160.1456 - val_loss: 159.6623
# Epoch 6/50
# 938/938 [==============================] - 5s 5ms/step - loss: 158.8512 - val_loss: 158.3822
# Epoch 7/50
# 938/938 [==============================] - 5s 5ms/step - loss: 157.7969 - val_loss: 157.4597
# Epoch 8/50
# 938/938 [==============================] - 5s 5ms/step - loss: 156.9130 - val_loss: 156.7713
# Epoch 9/50
# 938/938 [==============================] - 5s 5ms/step - loss: 156.1543 - val_loss: 156.1681
# Epoch 10/50
# 938/938 [==============================] - 5s 5ms/step - loss: 155.4870 - val_loss: 155.4810
# Epoch 11/50
# 938/938 [==============================] - 5s 5ms/step - loss: 154.8997 - val_loss: 155.0727
# Epoch 12/50
# 938/938 [==============================] - 5s 5ms/step - loss: 154.3637 - val_loss: 154.3349
# Epoch 13/50
# 938/938 [==============================] - 5s 5ms/step - loss: 153.8783 - val_loss: 154.0786
# Epoch 14/50
# 938/938 [==============================] - 5s 5ms/step - loss: 153.4617 - val_loss: 153.6444
# Epoch 15/50
# 938/938 [==============================] - 5s 5ms/step - loss: 153.0792 - val_loss: 153.2999
# Epoch 16/50
# 938/938 [==============================] - 5s 5ms/step - loss: 152.7397 - val_loss: 153.0520
# Epoch 17/50
# 938/938 [==============================] - 5s 5ms/step - loss: 152.4192 - val_loss: 152.6934
# Epoch 18/50
# 938/938 [==============================] - 5s 5ms/step - loss: 152.1683 - val_loss: 152.6413
# Epoch 19/50
# 938/938 [==============================] - 5s 5ms/step - loss: 151.9059 - val_loss: 152.1829
# Epoch 20/50
# 938/938 [==============================] - 5s 5ms/step - loss: 151.7239 - val_loss: 152.2358
# Epoch 21/50
# 938/938 [==============================] - 5s 5ms/step - loss: 151.4915 - val_loss: 151.9632
# Epoch 22/50
# 938/938 [==============================] - 5s 5ms/step - loss: 151.2661 - val_loss: 151.8497
# Epoch 23/50
# 938/938 [==============================] - 5s 5ms/step - loss: 151.1251 - val_loss: 151.7291
# Epoch 24/50
# 938/938 [==============================] - 5s 5ms/step - loss: 150.9472 - val_loss: 152.0434
# Epoch 25/50
# 938/938 [==============================] - 5s 5ms/step - loss: 150.7625 - val_loss: 151.5717
# Epoch 26/50
# 938/938 [==============================] - 5s 5ms/step - loss: 150.5900 - val_loss: 151.6320
# Epoch 27/50
# 938/938 [==============================] - 5s 5ms/step - loss: 150.4491 - val_loss: 151.4061
# Epoch 28/50
# 938/938 [==============================] - 5s 5ms/step - loss: 150.2999 - val_loss: 151.1641
# Epoch 29/50
# 938/938 [==============================] - 5s 5ms/step - loss: 150.1619 - val_loss: 151.0281
# Epoch 30/50
# 938/938 [==============================] - 5s 5ms/step - loss: 150.0128 - val_loss: 151.1506
# Epoch 31/50
# 938/938 [==============================] - 5s 5ms/step - loss: 149.8795 - val_loss: 150.8608
# Epoch 32/50
# 938/938 [==============================] - 5s 5ms/step - loss: 149.7700 - val_loss: 150.8007
# Epoch 33/50
# 938/938 [==============================] - 5s 5ms/step - loss: 149.6329 - val_loss: 150.6418
# Epoch 34/50
# 938/938 [==============================] - 5s 5ms/step - loss: 149.5232 - val_loss: 150.6609
# Epoch 35/50
# 938/938 [==============================] - 5s 5ms/step - loss: 149.4261 - val_loss: 151.0246
# Epoch 36/50
# 938/938 [==============================] - 5s 5ms/step - loss: 149.3139 - val_loss: 150.5191
# Epoch 37/50
# 938/938 [==============================] - 5s 5ms/step - loss: 149.2407 - val_loss: 150.6020
# Epoch 38/50
# 938/938 [==============================] - 5s 5ms/step - loss: 149.1154 - val_loss: 150.4494
# Epoch 39/50
# 938/938 [==============================] - 5s 5ms/step - loss: 149.0293 - val_loss: 150.4571
# Epoch 40/50
# 938/938 [==============================] - 4s 5ms/step - loss: 148.9084 - val_loss: 150.4106
# Epoch 41/50
# 938/938 [==============================] - 5s 5ms/step - loss: 148.8248 - val_loss: 150.1385
# Epoch 42/50
# 938/938 [==============================] - 5s 5ms/step - loss: 148.7340 - val_loss: 150.4138
# Epoch 43/50
# 938/938 [==============================] - 5s 5ms/step - loss: 148.6960 - val_loss: 150.2913
# Epoch 44/50
# 938/938 [==============================] - 5s 5ms/step - loss: 148.6032 - val_loss: 150.0101
# Epoch 45/50
# 938/938 [==============================] - 5s 5ms/step - loss: 148.5222 - val_loss: 150.7673
# Epoch 46/50
# 938/938 [==============================] - 5s 5ms/step - loss: 148.4595 - val_loss: 150.1124
# Epoch 47/50
# 938/938 [==============================] - 5s 5ms/step - loss: 148.3834 - val_loss: 150.5003
# Epoch 48/50
# 938/938 [==============================] - 5s 5ms/step - loss: 148.2886 - val_loss: 150.2600
# Epoch 49/50
# 938/938 [==============================] - 5s 5ms/step - loss: 148.2356 - val_loss: 149.9830
# Epoch 50/50
# 938/938 [==============================] - 5s 5ms/step - loss: 148.1721 - val_loss: 150.1512

# %% [markdown]
# Load $\mu$ and plot it based on different classes

# %%
vae_z = encoder.predict(x_test, batch_size=100)
np.savetxt('vae_z.txt',np.c_[vae_z,Y_test],fmt='%.3e',delimiter=",",header='x,y,label',comments='')
vae_z = pd.read_csv('vae_z.txt')
plt.figure(figsize=(6, 6))
plt.scatter(vae_z['x'], vae_z['y'], c=vae_z['label'], alpha=.4, s=3**2, cmap='viridis')
plt.colorbar()
plt.show()

# %% [markdown]
# # CVAE

# %% [markdown]
# VAEs are designed to estimate the unknown probability distribution $p_\theta(x)$ for the given dataset $X$ using a Gaussian in latent space. Instead, CVAE is try to estimate $p_\theta(x|y)$, where $y$ is the label from dataset $X$.
#
# Similarly,
# \begin{eqnarray*}
# logp_\theta(x|y) &=& E_{z\sim q_{\phi(z|x,y)}}[logp_{\theta}(x|y)] \qquad\text{By p(x) not depend on z}\\
#                  &=& E_{z}[log\frac{p_{\theta}(x,y,z)}{p_{\theta}(z|x,y)p_\theta(y)}] \qquad\text{By bayer's rule}\\
#                  &=& E_z[log\frac{p_{\theta}(x,y,z)}{p_\theta(y)}\frac{1}{p_{\theta}(z|x,y)}\frac{q_{\phi}(z|x,y)}{q_{\phi}(z|x,y)}]\\
#                  &=& \underbrace{E_z[log\frac{p_\theta(x,z|y)}{q_\phi(z|x,y)}]}_{\mathcal{L(\theta,\phi;x})}+D_{KL}(q_\phi(z|x,y)\|p_\theta(z|x,y))
# \end{eqnarray*}
# $\mathcal{L(\theta,\phi;x})$ is lower bound of $logp_\theta(x|y)$.
# \begin{eqnarray*}
# \mathcal{L(\theta,\phi;x}) &=& E_{z\sim q(z|x,y)}[log\frac{p_\theta(x|z,y)p_\theta(z|y)}{q_\phi(z|x,y)}]\\
#     &=& E_z[log\frac{p_\theta(z|y)}{q_\phi(z|x,y)}]+E_z[logp_\theta(x|z,y)]\\
#     &=& -D_{KL}(q_\phi(z|x,y)\|p_\theta(z|y))+E_z[logp_\theta(x|z,y)]
# \end{eqnarray*}

# %% [markdown]
# Different from VAE, we use a Gaussion Mixture model for better seperation in latent space, let  $p_\theta(z|y)=\mathcal{N}(\mu_y,I)$, where $\mu_y$ is different by classes. Since $p(y)$ is known and $p(z|y)$ is given, we have $p(z|x,y)=p(z|x)$
#
# \begin{eqnarray*}
# \mathcal{L(\theta,\phi;x}) &=& -D_{KL}(q_\phi(z|x)\|p_\theta(z|y))+E_z[logp_\theta(x|z,y)] \\
#     &=& -E_{z\sim q_\phi(z|x)}[log\frac{q_\phi(z|x)}{p_\theta(z|y)}]+\frac{1}{L}\mathop{\sum}_{l=1}^{L}(logp_\theta(x|z^{(l)},y))\\
#     &=& -E_z[-\frac{1}{2}\mathop{\sum}_{i=1}^{d}(log\sigma^2_i(x)-\|z-\mu_y\|^2)]+\frac{1}{L}\mathop{\sum}_{l=1}^{L}(logp_\theta(x|z^{(l)},y))\\
#     &\sim& \frac{1}{2}\mathop{\sum}_{i=1}^{d}(log\sigma^2_i(x)-\|z-\mu_y\|^2)+\frac{1}{L}\mathop{\sum}_{l=1}^{L}(logp_\theta(x|z^{(l)},y))\\
# \end{eqnarray*}
# where $z^{(l)}$ is resampled as in VAE.

# %% [markdown]
# ### Build the CVAE model
# By deriving the loss function as above, we can see that the main difference is we use GMM(Gaussion Mixture Model). So it is same for encoder and decoder part as in VAE.

# %%
original_dim, intermediate_dim, latent_dim = 784, 256, 2
num_classes = 10

decoder = Sequential([
    Dense(intermediate_dim, input_dim=latent_dim, activation='relu'),
    Dense(original_dim, activation='sigmoid')
])

label = Input(shape=(num_classes,))
x = Input(shape=(original_dim,))
h = Dense(intermediate_dim, activation='relu')(x)

z_mu = Dense(latent_dim)(h)
z_log_var = Dense(latent_dim)(h)

z = Lambda(sampling, output_shape=(latent_dim,))([z_mu, z_log_var]) # sampling

x_recon = decoder(z)

# %% [markdown]
# In order to train $\mu_y$, we build a Gaussian layer with weight matrix shape 10*2 to represent $\mu_y$ for 10 different classes in MINST.

# %%
class Gaussian(Layer):
    """这是个简单的层，定义q(z|y)中的均值参数，每个类别配一个均值。
    然后输出“z - 均值”，为后面计算loss准备。
    """
    def __init__(self, num_classes, **kwargs):
        self.num_classes = num_classes
        super(Gaussian, self).__init__(**kwargs)
    def build(self, input_shape):
        latent_dim = input_shape[-1]
        self.mean = self.add_weight(name='mean',
                                    shape=(self.num_classes, latent_dim),
                                    initializer='zeros')
    def call(self, inputs):
        z = inputs # z.shape=(batch_size, latent_dim)
        z = K.expand_dims(z, 1)
        return z - K.expand_dims(self.mean, 0)
    def compute_output_shape(self, input_shape):
        return (None, self.num_classes, input_shape[-1])
    def get_config(self):
        config = super().get_config().copy()
        config.update({
            'num_classes': self.num_classes
        })
        return config
    
gaussian = Gaussian(num_classes)
z_prior_mean = gaussian(z)

# 建立模型
cvae = Model([x,label], [x_recon, z_prior_mean])
encoder = Model([x,label], z_mu)

# %% [markdown]
# Loss function is
# \begin{eqnarray}
# -\mathcal{L} &=& D_{KL}(q_\phi(z|x)\|p_\theta(z|y))-E_z[logp_\theta(x|z,y)] \\
# &\sim& -\frac{1}{2}\mathop{\sum}_{i=1}^{d}(log\sigma^2_i(x)-\|z-\mu_y\|^2)-\frac{1}{L}\mathop{\sum}_{l=1}^{L}(logp_\theta(x|z^{(l)},y))
# \end{eqnarray}
# which derived above. By intuition, $D_{KL}(q_\phi(z|x)\|p_\theta(z|y))$ is for cluster. Making $p(z|y)$ in its own Gaussian model by different classes. $logp_\theta(x|z,y)$ is for reducing reconstruction error, to save more information in $z$. So in order to have a better seperation, we add weight $\lambda=0.3$ to $E_z[logp_\theta(x|z,y)]$.

# %%
# 下面一大通都是为了定义loss
z_mu = K.expand_dims(z_mu, 1)
z_log_var = K.expand_dims(z_log_var, 1)

lamb = 0.3 # 这是重构误差的权重，它的相反数就是重构方差，越大意味着方差越小。
xent_loss = 0.5 * K.mean((x - x_recon)**2, 0)
kl_loss = - 0.5 * (z_log_var - K.square(z_prior_mean))
kl_loss = K.mean(K.batch_dot(K.expand_dims(label, 1), kl_loss), 0)
# cat_loss = K.mean(y * K.log(y + K.epsilon()), 0)
cvae_loss = lamb * K.sum(xent_loss) + K.sum(kl_loss)# + K.sum(cat_loss)

cvae.add_loss(cvae_loss)
cvae.compile(optimizer='adam')

(x_train, Y_train), (x_test, Y_test) = mnist.load_data()
x_train = x_train.reshape(-1, original_dim).astype(np.float32) / 255.
x_test = x_test.reshape(-1, original_dim).astype(np.float32) / 255.

y_train = to_categorical(Y_train)
y_test = to_categorical(Y_test)

# %% [markdown]
# The $\mu$ for test dataset in latent space has been saved in text file. If you want to repeat it, you can run the following code.

# %%
cvae.fit([x_train,y_train],
        shuffle=True,
        epochs=50,
        batch_size=64,
        validation_data=[x_test,y_test])
# Out:
# Epoch 1/50
# 938/938 [==============================] - 5s 4ms/step - loss: 73.5099 - val_loss: 71.7939
# Epoch 2/50
# 938/938 [==============================] - 4s 4ms/step - loss: 71.5949 - val_loss: 71.6667
# Epoch 3/50
# 938/938 [==============================] - 4s 4ms/step - loss: 71.6010 - val_loss: 71.8025
# Epoch 4/50
# 938/938 [==============================] - 4s 4ms/step - loss: 71.6494 - val_loss: 71.6230
# Epoch 5/50
# 938/938 [==============================] - 4s 4ms/step - loss: 72.4374 - val_loss: 71.9025
# Epoch 6/50
# 938/938 [==============================] - 4s 4ms/step - loss: 71.7641 - val_loss: 70.9517
# Epoch 7/50
# 938/938 [==============================] - 4s 4ms/step - loss: 72.0763 - val_loss: 72.4002
# Epoch 8/50
# 938/938 [==============================] - 4s 4ms/step - loss: 71.9339 - val_loss: 70.7948
# Epoch 9/50
# 938/938 [==============================] - 4s 4ms/step - loss: 72.0964 - val_loss: 71.1164
# Epoch 10/50
# 938/938 [==============================] - 4s 4ms/step - loss: 71.5118 - val_loss: 71.9317
# Epoch 11/50
# 938/938 [==============================] - 4s 4ms/step - loss: 71.9525 - val_loss: 71.8883
# Epoch 12/50
# 938/938 [==============================] - 4s 4ms/step - loss: 72.3772 - val_loss: 72.0274
# Epoch 13/50
# 938/938 [==============================] - 4s 4ms/step - loss: 72.1388 - val_loss: 71.9207
# Epoch 14/50
# 938/938 [==============================] - 4s 4ms/step - loss: 71.8665 - val_loss: 73.0185
# Epoch 15/50
# 938/938 [==============================] - 4s 4ms/step - loss: 71.8744 - val_loss: 72.6416
# Epoch 16/50
# 938/938 [==============================] - 4s 4ms/step - loss: 71.9226 - val_loss: 70.9660
# Epoch 17/50
# 938/938 [==============================] - 4s 4ms/step - loss: 72.0690 - val_loss: 71.9132
# Epoch 18/50
# 938/938 [==============================] - 4s 4ms/step - loss: 72.4087 - val_loss: 70.8948
# Epoch 19/50
# 938/938 [==============================] - 4s 4ms/step - loss: 71.5620 - val_loss: 71.3021
# Epoch 20/50
# 938/938 [==============================] - 4s 4ms/step - loss: 71.6507 - val_loss: 72.0608
# Epoch 21/50
# 938/938 [==============================] - 4s 4ms/step - loss: 71.4206 - val_loss: 72.8276
# Epoch 22/50
# 938/938 [==============================] - 4s 4ms/step - loss: 71.9857 - val_loss: 71.8400
# Epoch 23/50
# 938/938 [==============================] - 4s 4ms/step - loss: 72.1962 - val_loss: 71.4959
# Epoch 24/50
# 938/938 [==============================] - 4s 4ms/step - loss: 71.4996 - val_loss: 71.9325
# Epoch 25/50
# 938/938 [==============================] - 4s 4ms/step - loss: 71.9694 - val_loss: 71.6440
# Epoch 26/50
# 938/938 [==============================] - 4s 4ms/step - loss: 71.6485 - val_loss: 71.5057
# Epoch 27/50
# 938/938 [==============================] - 4s 4ms/step - loss: 71.8034 - val_loss: 71.3334
# Epoch 28/50
# 938/938 [==============================] - 4s 4ms/step - loss: 71.9810 - val_loss: 70.4081
# Epoch 29/50
# 938/938 [==============================] - 4s 4ms/step - loss: 72.0613 - val_loss: 70.9442
# Epoch 30/50
# 938/938 [==============================] - 4s 4ms/step - loss: 72.0657 - val_loss: 71.7487
# Epoch 31/50
# 938/938 [==============================] - 4s 4ms/step - loss: 72.1012 - val_loss: 71.4790
# Epoch 32/50
# 938/938 [==============================] - 4s 4ms/step - loss: 71.4754 - val_loss: 72.2320
# Epoch 33/50
# 938/938 [==============================] - 4s 4ms/step - loss: 71.7291 - val_loss: 71.7661
# Epoch 34/50
# 938/938 [==============================] - 4s 4ms/step - loss: 71.9850 - val_loss: 70.4629
# Epoch 35/50
# 938/938 [==============================] - 4s 4ms/step - loss: 72.0090 - val_loss: 72.5399
# Epoch 36/50
# 938/938 [==============================] - 4s 4ms/step - loss: 71.8354 - val_loss: 71.5401
# Epoch 37/50
# 938/938 [==============================] - 4s 4ms/step - loss: 72.0552 - val_loss: 72.3158
# Epoch 38/50
# 938/938 [==============================] - 4s 4ms/step - loss: 71.8150 - val_loss: 72.3157
# Epoch 39/50
# 938/938 [==============================] - 4s 4ms/step - loss: 71.6900 - val_loss: 71.4410
# Epoch 40/50
# 938/938 [==============================] - 4s 4ms/step - loss: 71.8473 - val_loss: 71.4742
# Epoch 41/50
# 938/938 [==============================] - 4s 4ms/step - loss: 72.0620 - val_loss: 70.9133
# Epoch 42/50
# 938/938 [==============================] - 4s 4ms/step - loss: 72.2660 - val_loss: 70.9330
# Epoch 43/50
# 938/938 [==============================] - 4s 4ms/step - loss: 71.9264 - val_loss: 71.8741
# Epoch 44/50
# 938/938 [==============================] - 4s 4ms/step - loss: 71.9486 - val_loss: 71.4567
# Epoch 45/50
# 938/938 [==============================] - 4s 4ms/step - loss: 72.1677 - val_loss: 71.3446
# Epoch 46/50
# 938/938 [==============================] - 4s 4ms/step - loss: 71.2890 - val_loss: 72.4238
# Epoch 47/50
# 938/938 [==============================] - 4s 4ms/step - loss: 71.6432 - val_loss: 71.9884
# Epoch 48/50
# 938/938 [==============================] - 4s 4ms/step - loss: 71.9827 - val_loss: 72.6887
# Epoch 49/50
# 938/938 [==============================] - 4s 4ms/step - loss: 72.4776 - val_loss: 72.1700
# Epoch 50/50
# 938/938 [==============================] - 4s 4ms/step - loss: 72.3462 - val_loss: 72.6311

# %% [markdown]
# The following figures show that latent space of CVAE have better seperation than VAE. This can help us do anomaly detection.

# %%
cvae_z = encoder.predict([x_test,y_test], batch_size=100)
np.savetxt('cvae_z.txt',np.c_[cvae_z[:,0,:],Y_test],fmt='%.3e',delimiter=",",header='x,y,label',comments='')
vae_z = pd.read_csv('vae_z.txt')
cvae_z = pd.read_csv('cvae_z.txt')

fig, ax = plt.subplots(1,2,figsize=(16,7))
ax_0 = ax[0].scatter(cvae_z['x'], cvae_z['y'], c=cvae_z['label'], alpha=.4, s=3**2, cmap='viridis')
ax[0].set_title("CVAE latent space")
fig.colorbar(ax_0, ax=ax[0])

ax_1 = ax[1].scatter(vae_z['x'], vae_z['y'], c=vae_z['label'], alpha=.4, s=3**2, cmap='viridis')
ax[1].set_title("VAE latent space")
fig.colorbar(ax_0, ax=ax[1])
# fig.show()

# %% [markdown]
# # Anomaly detection

# %% [markdown]
# The results of running anomaly detection using the LOF algorithm on CVAE latent space over each class are shown as below.

# %%
from sklearn.neighbors import LocalOutlierFactor

idx = []
fig, ax = plt.subplots(5,2,figsize=(10,15))
ax = ax.flatten()
for num in range(10):
    mask = cvae_z['label']==num
    mask_idx = np.arange(cvae_z['label'].shape[0])[mask]
    X = cvae_z[mask]

    clf = LocalOutlierFactor(n_neighbors=30, contamination=0.5)
    y_pred = clf.fit_predict(vae_z[mask])
    X_scores = clf.negative_outlier_factor_
    radius = (X_scores.max() - X_scores) / (X_scores.max() - X_scores.min())
    idx.append(mask_idx[np.argmax(radius)])
    
    ax[num].title.set_text('LOF for number {}'.format(num))
    ax[num].scatter(X['x'], X['y'], color='b', s=3., label='Data points')
    # plot circles with radius proportional to the outlier scores
#     ax[num].scatter(X['x'], X['y'], s=1000 * radius, edgecolors='b',
#                 facecolors='none', label='Outlier scores')
    mask_ = radius>0.9 # np.argmax(radius)
    ax[num].scatter(X['x'][mask_], X['y'][mask_], color='b', s=3., label='Data points')
    ax[num].scatter(X['x'][mask_], X['y'][mask_], s=1000 * radius[mask_], edgecolors='r',
            facecolors='none', label='Outlier scores')

# %% [markdown]
# From each class we choose one anomaly point as an example. From the figue below, we can compare anomaly point in latent space and its image in original dataset.

# %%
fig = plt.figure(figsize=(10,10))

ax = fig.add_axes([0,0,1,1])
ax.scatter(cvae_z['x'], cvae_z['y'], c=cvae_z['label'], alpha=.4, s=3**2, cmap='viridis')
ax.set_title('examples of anomaly points')
plt.xlim([-6,6])
plt.ylim([-8,8])
plt.plot([cvae_z.iloc[idx[0]]['x'],0.35*12-6],[cvae_z.iloc[idx[0]]['y'],0.85*16-8],c='r')
plt.plot([cvae_z.iloc[idx[1]]['x'],0.8*12-6],[cvae_z.iloc[idx[1]]['y'],0.2*16-8],c='r')
plt.plot([cvae_z.iloc[idx[2]]['x'],0.2*12-6],[cvae_z.iloc[idx[2]]['y'],0.7*16-8],c='r')
plt.plot([cvae_z.iloc[idx[3]]['x'],0.5*12-6],[cvae_z.iloc[idx[3]]['y'],0.8*16-8],c='r')
plt.plot([cvae_z.iloc[idx[4]]['x'],0.4*12-6],[cvae_z.iloc[idx[4]]['y'],0.1*16-8],c='r')
plt.plot([cvae_z.iloc[idx[5]]['x'],0.8*12-6],[cvae_z.iloc[idx[5]]['y'],0.4*16-8],c='r')
plt.plot([cvae_z.iloc[idx[6]]['x'],0.1*12-6],[cvae_z.iloc[idx[6]]['y'],0.3*16-8],c='r')
plt.plot([cvae_z.iloc[idx[7]]['x'],0.1*12-6],[cvae_z.iloc[idx[7]]['y'],0.1*16-8],c='r')
plt.plot([cvae_z.iloc[idx[8]]['x'],0.8*12-6],[cvae_z.iloc[idx[8]]['y'],0.7*16-8],c='r')
plt.plot([cvae_z.iloc[idx[9]]['x'],0.5*12-6],[cvae_z.iloc[idx[9]]['y'],0.3*16-8],c='r')


left, bottom, width, height = 0.3, 0.85, 0.1, 0.1
ax2 = fig.add_axes([left, bottom, width, height])
plt.imshow(x_test[idx[0]].reshape([28,28]))
ax2.axis('off')
ax2.set_title('{}'.format(0))

left, bottom, width, height = 0.8, 0.15, 0.1, 0.1
ax2 = fig.add_axes([left, bottom, width, height])
plt.imshow(x_test[idx[1]].reshape([28,28]))
ax2.axis('off')
ax2.set_title('{}'.format(1))

left, bottom, width, height = 0.15, 0.7, 0.1, 0.1
ax2 = fig.add_axes([left, bottom, width, height])
plt.imshow(x_test[idx[2]].reshape([28,28]))
ax2.axis('off')
ax2.set_title('{}'.format(2))

left, bottom, width, height = 0.45, 0.8, 0.1, 0.1
ax2 = fig.add_axes([left, bottom, width, height])
plt.imshow(x_test[idx[3]].reshape([28,28]))
ax2.axis('off')
ax2.set_title('{}'.format(3))

left, bottom, width, height = 0.35, 0.1, 0.1, 0.1
ax2 = fig.add_axes([left, bottom, width, height])
plt.imshow(x_test[idx[4]].reshape([28,28]))
ax2.axis('off')
ax2.set_title('{}'.format(4))

left, bottom, width, height = 0.8, 0.35, 0.1, 0.1
ax2 = fig.add_axes([left, bottom, width, height])
plt.imshow(x_test[idx[5]].reshape([28,28]))
ax2.axis('off')
ax2.set_title('{}'.format(5))

left, bottom, width, height = 0.05, 0.3, 0.1, 0.1
ax2 = fig.add_axes([left, bottom, width, height])
plt.imshow(x_test[idx[6]].reshape([28,28]))
ax2.axis('off')
ax2.set_title('{}'.format(6))

left, bottom, width, height = 0.05, 0.1, 0.1, 0.1
ax2 = fig.add_axes([left, bottom, width, height])
plt.imshow(x_test[idx[7]].reshape([28,28]))
ax2.axis('off')
ax2.set_title('{}'.format(7))

left, bottom, width, height = 0.8, 0.65, 0.1, 0.1
ax2 = fig.add_axes([left, bottom, width, height])
plt.imshow(x_test[idx[8]].reshape([28,28]))
ax2.axis('off')
ax2.set_title('{}'.format(8))

left, bottom, width, height = 0.45, 0.2, 0.1, 0.1
ax2 = fig.add_axes([left, bottom, width, height])
plt.imshow(x_test[idx[9]].reshape([28,28]))
ax2.axis('off')
ax2.set_title('{}'.format(9))
# Out:
# Text(0.5, 1.0, '9')

# %% [markdown]
# <div id="refer-anchor-1"></div>
# [1]E. Norlander and A. Sopasakis, "Latent space conditioning for improved classification and anomaly detection"
#
# <div id="refer-anchor-2"></div>
# [2]https://tiao.io/post/tutorial-on-variational-autoencoders-with-a-concise-keras-implementation/#fn:1
#
# <div id="refer-anchor-3"></div>
# [3]https://github.com/bojone/vae/blob/master/vae_keras_cluster.py
#
# <div id="refer-anchor-4"></div>
# [4]D. P. Kingma and M. Welling, “Auto-Encoding Variational Bayes,” in Proceedings of the 2nd International Conference on Learning Representations (ICLR), 2014.

# %% [markdown]
# # VAE

# %%
#https://tiao.io/post/tutorial-on-variational-autoencoders-with-a-concise-keras-implementation/#fn:1
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import pandas as pd

import tensorflow as tf
from tensorflow.keras import backend as K

from tensorflow.keras.layers import Input, Dense, Lambda, Layer, Add, Multiply
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
#%conda env export > requirements.yml

# %%
def sampling(args):
    z_mu, z_log_var = args
    epsilon = K.random_normal(shape=(K.shape(z_mu)[0], latent_dim)) #default mean=0, stddev=1
    return z_mu + K.exp(.5*z_log_var) * epsilon

# %%
# biuld the model

original_dim, intermediate_dim, latent_dim = 784, 256, 2
batch_size = 100
epochs = 50

decoder = Sequential([
    Dense(intermediate_dim, input_dim=latent_dim, activation='relu'),
    Dense(original_dim, activation='sigmoid')
])

x = Input(shape=(original_dim,))
h = Dense(intermediate_dim, activation='relu')(x)

z_mu = Dense(latent_dim)(h)
z_log_var = Dense(latent_dim)(h)

z = Lambda(sampling, output_shape=(latent_dim,))([z_mu, z_log_var]) # sampling

x_recon = decoder(z)

vae = Model(inputs=x, outputs=x_recon)

#keras.losses.binary_crossentropy gives the mean over the last axis. we require the sum
xent_loss = K.sum(K.binary_crossentropy(x, x_recon), axis=-1) 
kl_loss = K.mean(- .5 * K.sum(1 + z_log_var - K.square(z_mu) - K.exp(z_log_var), axis=-1))
vae_loss = xent_loss + kl_loss

vae.add_loss(vae_loss)
vae.compile(optimizer='rmsprop')#, loss=nll)

# %%
# train the VAE on MNIST digits
(x_train, Y_train), (x_test, Y_test) = mnist.load_data()
x_train = x_train.reshape(-1, original_dim) / 255.
x_test = x_test.reshape(-1, original_dim) / 255.

vae.fit(x_train,
        x_train,
        shuffle=True,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(x_test, x_test))

encoder = Model(x, z_mu)

# encoder.save('encoder.h5')
# decoder.save('decoder.h5')
# vae.save('vae.h5')
# Out:
# Epoch 1/50
# 600/600 [==============================] - 19s 28ms/step - loss: 217.3122 - val_loss: 171.9512
# Epoch 2/50
# 600/600 [==============================] - 14s 23ms/step - loss: 170.8399 - val_loss: 167.7007
# Epoch 3/50
# 600/600 [==============================] - 15s 25ms/step - loss: 166.9669 - val_loss: 164.9505
# Epoch 4/50
# 600/600 [==============================] - 16s 27ms/step - loss: 164.1345 - val_loss: 163.3721
# Epoch 5/50
# 600/600 [==============================] - 14s 24ms/step - loss: 162.1369 - val_loss: 161.4744
# Epoch 6/50
# 600/600 [==============================] - 18s 30ms/step - loss: 160.9045 - val_loss: 159.9577
# Epoch 7/50
# 600/600 [==============================] - 11s 18ms/step - loss: 159.5575 - val_loss: 158.9932
# Epoch 8/50
# 600/600 [==============================] - 11s 18ms/step - loss: 158.5489 - val_loss: 157.9597
# Epoch 9/50
# 600/600 [==============================] - 10s 17ms/step - loss: 157.4834 - val_loss: 157.5768
# Epoch 10/50
# 600/600 [==============================] - 10s 17ms/step - loss: 157.1547 - val_loss: 156.9202
# Epoch 11/50
# 600/600 [==============================] - 15s 25ms/step - loss: 156.5468 - val_loss: 156.3694
# Epoch 12/50
# 600/600 [==============================] - 15s 25ms/step - loss: 155.7992 - val_loss: 155.8626
# Epoch 13/50
# 600/600 [==============================] - 17s 28ms/step - loss: 155.6021 - val_loss: 156.2138
# Epoch 14/50
# 600/600 [==============================] - 14s 23ms/step - loss: 155.4532 - val_loss: 155.7037
# Epoch 15/50
# 600/600 [==============================] - 13s 22ms/step - loss: 154.9549 - val_loss: 155.2759
# Epoch 16/50
# 600/600 [==============================] - 13s 21ms/step - loss: 153.8188 - val_loss: 154.7401
# Epoch 17/50
# 600/600 [==============================] - 17s 28ms/step - loss: 154.2512 - val_loss: 154.6771
# Epoch 18/50
# 600/600 [==============================] - 16s 26ms/step - loss: 154.2079 - val_loss: 154.5519
# Epoch 19/50
# 600/600 [==============================] - 14s 24ms/step - loss: 153.5892 - val_loss: 154.3109
# Epoch 20/50
# 600/600 [==============================] - 13s 22ms/step - loss: 153.2945 - val_loss: 154.0772
# Epoch 21/50
# 600/600 [==============================] - 14s 23ms/step - loss: 153.0146 - val_loss: 154.2269
# Epoch 22/50
# 600/600 [==============================] - 14s 23ms/step - loss: 153.2475 - val_loss: 153.7185
# Epoch 23/50
# 600/600 [==============================] - 14s 23ms/step - loss: 152.9359 - val_loss: 153.4511
# Epoch 24/50
# 600/600 [==============================] - 14s 23ms/step - loss: 152.4904 - val_loss: 153.3761
# Epoch 25/50
# 600/600 [==============================] - 14s 23ms/step - loss: 152.1142 - val_loss: 153.3169
# Epoch 26/50
# 600/600 [==============================] - 14s 23ms/step - loss: 151.9857 - val_loss: 153.1335
# Epoch 27/50
# 600/600 [==============================] - 15s 24ms/step - loss: 151.8222 - val_loss: 153.6040
# Epoch 28/50
# 600/600 [==============================] - 15s 24ms/step - loss: 151.8905 - val_loss: 153.1832
# Epoch 29/50
# 600/600 [==============================] - 15s 24ms/step - loss: 151.9778 - val_loss: 153.2235
# Epoch 30/50
# 600/600 [==============================] - 15s 24ms/step - loss: 151.4488 - val_loss: 152.6408
# Epoch 31/50
# 600/600 [==============================] - 14s 24ms/step - loss: 151.8090 - val_loss: 152.5527
# Epoch 32/50
# 600/600 [==============================] - 14s 24ms/step - loss: 151.2802 - val_loss: 152.5630
# Epoch 33/50
# 600/600 [==============================] - 15s 24ms/step - loss: 151.3362 - val_loss: 152.4759
# Epoch 34/50
# 600/600 [==============================] - 14s 23ms/step - loss: 150.7346 - val_loss: 152.2467
# Epoch 35/50
# 600/600 [==============================] - 14s 24ms/step - loss: 150.8552 - val_loss: 152.3070
# Epoch 36/50
# 600/600 [==============================] - 15s 25ms/step - loss: 151.0677 - val_loss: 152.0499
# Epoch 37/50
# 600/600 [==============================] - 15s 25ms/step - loss: 150.5407 - val_loss: 152.2119
# Epoch 38/50
# 600/600 [==============================] - 16s 26ms/step - loss: 150.3731 - val_loss: 151.8784
# Epoch 39/50
# 600/600 [==============================] - 14s 23ms/step - loss: 150.0338 - val_loss: 151.8092
# Epoch 40/50
# 600/600 [==============================] - 13s 22ms/step - loss: 149.8959 - val_loss: 151.6673
# Epoch 41/50
# 600/600 [==============================] - 14s 23ms/step - loss: 150.3827 - val_loss: 151.8350
# Epoch 42/50
# 600/600 [==============================] - 13s 22ms/step - loss: 149.8523 - val_loss: 152.1713
# Epoch 43/50
# 600/600 [==============================] - 15s 24ms/step - loss: 150.0750 - val_loss: 151.5737
# Epoch 44/50
# 600/600 [==============================] - 14s 24ms/step - loss: 150.1213 - val_loss: 151.4398
# Epoch 45/50
# 600/600 [==============================] - 17s 28ms/step - loss: 149.8375 - val_loss: 151.4380
# Epoch 46/50
# 600/600 [==============================] - 17s 28ms/step - loss: 149.0468 - val_loss: 151.2663
# Epoch 47/50
# 600/600 [==============================] - 17s 28ms/step - loss: 149.3083 - val_loss: 151.3733
# Epoch 48/50
# 600/600 [==============================] - 16s 27ms/step - loss: 149.4929 - val_loss: 151.2565
# Epoch 49/50
# 600/600 [==============================] - 16s 27ms/step - loss: 149.1912 - val_loss: 151.3428
# Epoch 50/50
# 600/600 [==============================] - 16s 27ms/step - loss: 149.1488 - val_loss: 151.2023

# %%
# encoder = tf.keras.models.load_model('encoder.h5', custom_objects={'KLDivergenceLayer':KLDivergenceLayer()})
# decoder = tf.keras.models.load_model('decoder.h5', custom_objects={'KLDivergenceLayer':KLDivergenceLayer()})
# vae = tf.keras.models.load_model('vae.h5', custom_objects={'KLDivergenceLayer':KLDivergenceLayer(), 'nll':nll})

# display a 2D plot of the digit classes in the latent space
z_test = encoder.predict(x_test, batch_size=batch_size)
# np.savetxt('vae_z.txt',np.c_[z_test,Y_test],fmt='%.3e',delimiter=",",header='x,y,label',comments='')
plt.figure(figsize=(6, 6))
plt.scatter(z_test[:, 0], z_test[:, 1], c=y_test,
            alpha=.4, s=3**2, cmap='viridis')
plt.colorbar()
plt.show()

# display a 2D manifold of the digits
n = 15  # figure with 15x15 digits
digit_size = 28

# linearly spaced coordinates on the unit square were transformed
# through the inverse CDF (ppf) of the Gaussian to produce values
# of the latent variables z, since the prior of the latent space
# is Gaussian
u_grid = np.dstack(np.meshgrid(np.linspace(0.05, 0.95, n),
                               np.linspace(0.05, 0.95, n)))
z_grid = norm.ppf(u_grid)
x_decoded = decoder.predict(z_grid.reshape(n*n, 2))
x_decoded = x_decoded.reshape(n, n, digit_size, digit_size)

plt.figure(figsize=(10, 10))
plt.imshow(np.block(list(map(list, x_decoded))), cmap='gray')
plt.show()

# %% [markdown]
# ## CVAE

# %%
#https://github.com/bojone/vae/blob/master/vae_keras_cluster.py
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import concatenate

original_dim, intermediate_dim, latent_dim = 784, 256, 2
batch_size = 100
epochs = 50

decoder = Sequential([
    Dense(intermediate_dim, input_dim=latent_dim, activation='relu'),
    Dense(original_dim, activation='sigmoid')
])

label = Input(shape=(num_classes,))
x = Input(shape=(original_dim,))
h = Dense(intermediate_dim, activation='relu')(x)

z_mu = Dense(latent_dim)(h)
z_log_var = Dense(latent_dim)(h)

z = Lambda(sampling, output_shape=(latent_dim,))([z_mu, z_log_var]) # sampling

x_recon = decoder(z)

class Gaussian(Layer):
    """这是个简单的层，定义q(z|y)中的均值参数，每个类别配一个均值。
    然后输出“z - 均值”，为后面计算loss准备。
    """
    def __init__(self, num_classes, **kwargs):
        self.num_classes = num_classes
        super(Gaussian, self).__init__(**kwargs)
    def build(self, input_shape):
        latent_dim = input_shape[-1]
        self.mean = self.add_weight(name='mean',
                                    shape=(self.num_classes, latent_dim),
                                    initializer='zeros')
    def call(self, inputs):
        z = inputs # z.shape=(batch_size, latent_dim)
        z = K.expand_dims(z, 1)
        return z - K.expand_dims(self.mean, 0)
    def compute_output_shape(self, input_shape):
        return (None, self.num_classes, input_shape[-1])
    def get_config(self):
        config = super().get_config().copy()
        config.update({
            'num_classes': self.num_classes
        })
        return config
    
gaussian = Gaussian(num_classes)
z_prior_mean = gaussian(z)


# 建立模型
cvae = Model([x,label], [x_recon, z_prior_mean])

# 下面一大通都是为了定义loss
z_mu = K.expand_dims(z_mu, 1)
z_log_var = K.expand_dims(z_log_var, 1)

lamb = 0.3 # 这是重构误差的权重，它的相反数就是重构方差，越大意味着方差越小。
xent_loss = 0.5 * K.mean((x - x_recon)**2, 0)
kl_loss = - 0.5 * (z_log_var - K.square(z_prior_mean))
kl_loss = K.mean(K.batch_dot(K.expand_dims(label, 1), kl_loss), 0)
# cat_loss = K.mean(y * K.log(y + K.epsilon()), 0)
cvae_loss = lamb * K.sum(xent_loss) + K.sum(kl_loss)# + K.sum(cat_loss)


cvae.add_loss(cvae_loss)
cvae.compile(optimizer='adam')
# cvae.summary()

# %%
(x_train, Y_train), (x_test, Y_test) = mnist.load_data()
x_train = x_train.reshape(-1, original_dim).astype(np.float32) / 255.
x_test = x_test.reshape(-1, original_dim).astype(np.float32) / 255.

y_train = to_categorical(Y_train)
y_test = to_categorical(Y_test)

cvae.fit([x_train,y_train],
        shuffle=True,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=[x_test,y_test])


encoder = Model([x,label], z_mu)

# encoder.save('cvae_encoder.h5')
# decoder.save('cvae_decoder.h5')
# cvae.save('cvae.h5')
# Out:
# Epoch 1/50
# 288/600 [=============>................] - ETA: 4s - loss: 15.2584
# ---------------------------------------------------------------------------
# _NotOkStatusException                     Traceback (most recent call last)
# <ipython-input-38-90725f30435f> in <module>
#      10         epochs=epochs,
#      11         batch_size=batch_size,
# ---> 12         validation_data=[x_test,y_test])
#      13
#      14
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2939     with self._lock:
#    2940       (graph_function,
# -> 2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
#    2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3317
#    3318     cache_key_context = self._cache_key_context()
# -> 3319     cache_key = self._cache_key(args, kwargs, cache_key_context)
#    3320
#    3321     try:
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _cache_key(self, args, kwargs, cache_key_context, include_tensor_ranks_only)
#    3097       inputs = (args, kwargs) if kwargs else args
#    3098       input_signature = pywrap_tfe.TFE_Py_EncodeArg(inputs,
# -> 3099                                                     include_tensor_ranks_only)
#    3100       hashable_input_signature = _make_input_signature_hashable(input_signature)
#    3101     else:
#
# _NotOkStatusException: InvalidArgumentError: Error while reading CompositeTensor._type_spec.

# %%
encoder = tf.keras.models.load_model('cvae_encoder.h5', custom_objects={'Gaussian':Gaussian(num_classes)})
decoder = tf.keras.models.load_model('cvae_decoder.h5', custom_objects={'Gaussian':Gaussian(num_classes)})
cvae = tf.keras.models.load_model('cvae.h5', custom_objects={'Gaussian':Gaussian(num_classes)})

# display a 2D plot of the digit classes in the latent space
z_test = encoder.predict([x_test,y_test], batch_size=batch_size)
# np.savetxt('cvae_z.txt',np.c_[z_test,Y_test],fmt='%.3e',delimiter=",",header='x,y,label',comments='')
z_test = z_test.squeeze()
plt.figure(figsize=(6, 6))
plt.scatter(z_test[:, 0], z_test[:, 1], c=Y_test,
            alpha=.4, s=3**2, cmap='viridis')
plt.colorbar()
plt.show()
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# ### Anomaly detection

# %%
from sklearn.neighbors import LocalOutlierFactor

y = np.argmax(y_test, axis=-1)
mask = y==2
X = encoder.predict([x_test[mask],y_test[mask]], batch_size=batch_size)

clf = LocalOutlierFactor(n_neighbors=20, contamination=0.1)
y_pred = clf.fit_predict(X)
X_scores = clf.negative_outlier_factor_


plt.title("Local Outlier Factor (LOF)")
plt.scatter(X[:, 0], X[:, 1], color='k', s=3., label='Data points')
# plot circles with radius proportional to the outlier scores
radius = (X_scores.max() - X_scores) / (X_scores.max() - X_scores.min())
plt.scatter(X[:, 0], X[:, 1], s=1000 * radius, edgecolors='r',
            facecolors='none', label='Outlier scores')

# %%
mask_=radius>0.4
plt.scatter(X[:, 0][mask_], X[:, 1][mask_], color='k', s=3., label='Data points')
plt.scatter(X[:, 0][mask_], X[:, 1][mask_], s=1000 * radius[mask_], edgecolors='r',
            facecolors='none', label='Outlier scores')

# %%
for layer in vae.layers:
    weights = layer.get_weights()  # list of numpy array
    print(layer.name, weights)

# %% [markdown]
# # Other coding style for keras

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
from tensorflow.keras import layers

try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass
import tensorflow as tf
import numpy as np

tf.keras.backend.clear_session()  # For easy reset of notebook state.


class Sampling(layers.Layer):
  """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

  def call(self, inputs):
    z_mean, z_log_var = inputs
    batch = tf.shape(z_mean)[0]
    dim = tf.shape(z_mean)[1]
    epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
    return z_mean + tf.exp(0.5 * z_log_var) * epsilon


class Encoder(layers.Layer):
  """Maps MNIST digits to a triplet (z_mean, z_log_var, z)."""

  def __init__(self,
               latent_dim=32,
               intermediate_dim=64,
               name='encoder',
               **kwargs):
    super(Encoder, self).__init__(name=name, **kwargs)
    self.dense_proj = layers.Dense(intermediate_dim, activation='relu')
    self.dense_mean = layers.Dense(latent_dim)
    self.dense_log_var = layers.Dense(latent_dim)
    self.sampling = Sampling()

  def call(self, inputs):
    x = self.dense_proj(inputs)
    z_mean = self.dense_mean(x)
    z_log_var = self.dense_log_var(x)
    z = self.sampling((z_mean, z_log_var))
    return z_mean, z_log_var, z


class Decoder(layers.Layer):
  """Converts z, the encoded digit vector, back into a readable digit."""

  def __init__(self,
               original_dim,
               intermediate_dim=64,
               name='decoder',
               **kwargs):
    super(Decoder, self).__init__(name=name, **kwargs)
    self.dense_proj = layers.Dense(intermediate_dim, activation='relu')
    self.dense_output = layers.Dense(original_dim, activation='sigmoid')

  def call(self, inputs):
    x = self.dense_proj(inputs)
    return self.dense_output(x)


class VariationalAutoEncoder(tf.keras.Model):
  """Combines the encoder and decoder into an end-to-end model for training."""

  def __init__(self,
               original_dim,
               intermediate_dim=64,
               latent_dim=32,
               name='autoencoder',
               **kwargs):
    super(VariationalAutoEncoder, self).__init__(name=name, **kwargs)
    self.original_dim = original_dim
    self.encoder = Encoder(latent_dim=latent_dim,
                           intermediate_dim=intermediate_dim)
    self.decoder = Decoder(original_dim, intermediate_dim=intermediate_dim)

  def call(self, inputs):
    # self._set_inputs(inputs)
    z_mean, z_log_var, z = self.encoder(inputs)
    reconstructed = self.decoder(z)
    # Add KL divergence regularization loss.
    kl_loss = - 0.5 * tf.reduce_mean(
        z_log_var - tf.square(z_mean) - tf.exp(z_log_var) + 1)
    self.add_loss(kl_loss)
    return reconstructed

# %%
original_dim = 784
vae = VariationalAutoEncoder(original_dim, 256, 2)  #, input_shape=(784,)

optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
mse_loss_fn = tf.keras.losses.BinaryCrossentropy()##tf.keras.losses.MeanSquaredError()

loss_metric = tf.keras.metrics.Mean()

# train the VAE on MNIST digits
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train = x_train.reshape(-1, original_dim).astype(np.float32) / 255.
x_test = x_test.reshape(-1, original_dim).astype(np.float32) / 255.

train_dataset = tf.data.Dataset.from_tensor_slices(x_train)
train_dataset = train_dataset.shuffle(buffer_size=1024).batch(64)

# Iterate over epochs.
for epoch in range(50):
  print('Start of epoch %d' % (epoch,))

  # Iterate over the batches of the dataset.
  for step, x_batch_train in enumerate(train_dataset):
    with tf.GradientTape() as tape:
      # !!! uncomment the following two lines to use workaround and skip !!!
      # if step == 0 and epoch == 0:
      #   vae._set_inputs(x_batch_train)
      reconstructed = vae(x_batch_train)
      # Compute reconstruction loss
      #x_batch_train = tf.cast(x_batch_train, tf.float32)
#       loss = nll(x_batch_train, reconstructed) #if use mse_loss_fn as loss function, need multiply 100.
      loss = 100*mse_loss_fn(x_batch_train, reconstructed)
      loss += sum(vae.losses)  # Add KLD regularization loss

    grads = tape.gradient(loss, vae.trainable_weights)
    optimizer.apply_gradients(zip(grads, vae.trainable_weights))

    loss_metric(loss)
    if step % 100 == 0:
      print('step %s: mean loss = %s' % (step, loss_metric.result()))
vae.save('vae')


# # or train like this
# vae = VariationalAutoEncoder(original_dim, 256, 2)  #, input_shape=(784,)
# vae.compile(optimizer='rmsprop', loss=nll)

# vae.fit(x_train,
#         x_train,
#         shuffle=True,
#         epochs=50,
#         batch_size=100,
#         validation_data=(x_test, x_test))
# Out:
# Start of epoch 0
# step 0: mean loss = tf.Tensor(69.520096, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(38.369698, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(32.546906, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(30.225502, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(28.941887, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(28.009687, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(27.37552, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(26.867733, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(26.464987, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(26.099138, shape=(), dtype=float32)
# Start of epoch 1
# step 0: mean loss = tf.Tensor(25.989872, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(25.721655, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(25.491507, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(25.311552, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(25.148596, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(24.99005, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(24.861584, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(24.74058, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(24.642427, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(24.528154, shape=(), dtype=float32)
# Start of epoch 2
# step 0: mean loss = tf.Tensor(24.494152, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(24.405403, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(24.323229, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(24.256672, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(24.193121, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(24.124157, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(24.06737, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(24.010967, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(23.968216, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(23.905857, shape=(), dtype=float32)
# Start of epoch 3
# step 0: mean loss = tf.Tensor(23.889242, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(23.841618, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(23.79527, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(23.758657, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(23.724272, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(23.683407, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(23.64716, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(23.612, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(23.581795, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(23.543518, shape=(), dtype=float32)
# Start of epoch 4
# step 0: mean loss = tf.Tensor(23.531748, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(23.499262, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(23.468815, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(23.444632, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(23.41963, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(23.389956, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(23.366785, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(23.339949, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(23.32037, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(23.29089, shape=(), dtype=float32)
# Start of epoch 5
# step 0: mean loss = tf.Tensor(23.281786, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(23.257639, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(23.236374, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(23.217714, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(23.197798, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(23.177546, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(23.158567, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(23.138126, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(23.12321, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(23.100002, shape=(), dtype=float32)
# Start of epoch 6
# step 0: mean loss = tf.Tensor(23.093391, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(23.07465, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(23.056507, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(23.042234, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(23.027971, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(23.01015, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(22.995764, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(22.979437, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(22.966757, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(22.948223, shape=(), dtype=float32)
# Start of epoch 7
# step 0: mean loss = tf.Tensor(22.942234, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(22.926792, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(22.912436, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(22.900473, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(22.888088, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(22.87394, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(22.860811, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(22.847408, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(22.838037, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(22.821394, shape=(), dtype=float32)
# Start of epoch 8
# step 0: mean loss = tf.Tensor(22.816008, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(22.801977, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(22.790203, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(22.780472, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(22.769442, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(22.757841, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(22.746807, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(22.734678, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(22.726274, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(22.712603, shape=(), dtype=float32)
# Start of epoch 9
# step 0: mean loss = tf.Tensor(22.707838, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(22.695255, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(22.685295, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(22.676538, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(22.667337, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(22.65702, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(22.647928, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(22.637167, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(22.629532, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(22.617535, shape=(), dtype=float32)
# Start of epoch 10
# step 0: mean loss = tf.Tensor(22.613403, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(22.602348, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(22.593182, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(22.585684, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(22.577225, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(22.56761, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(22.559689, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(22.549633, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(22.543419, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(22.532482, shape=(), dtype=float32)
# Start of epoch 11
# step 0: mean loss = tf.Tensor(22.528866, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(22.519455, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(22.510633, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(22.504126, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(22.496847, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(22.488722, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(22.48106, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(22.472528, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(22.466784, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(22.456581, shape=(), dtype=float32)
# Start of epoch 12
# step 0: mean loss = tf.Tensor(22.45313, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(22.444475, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(22.437456, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(22.431202, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(22.424171, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(22.417082, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(22.410192, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(22.402403, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(22.397463, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(22.38876, shape=(), dtype=float32)
# Start of epoch 13
# step 0: mean loss = tf.Tensor(22.385384, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(22.37769, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(22.370646, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(22.365242, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(22.359205, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(22.352535, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(22.3461, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(22.33946, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(22.334951, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(22.326591, shape=(), dtype=float32)
# Start of epoch 14
# step 0: mean loss = tf.Tensor(22.323683, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(22.316286, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(22.310291, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(22.305311, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(22.29963, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(22.293695, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(22.28751, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(22.28151, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(22.277027, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(22.269886, shape=(), dtype=float32)
# Start of epoch 15
# step 0: mean loss = tf.Tensor(22.267168, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(22.260439, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(22.254766, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(22.25067, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(22.245283, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(22.240019, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(22.234789, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(22.228996, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(22.225054, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(22.217989, shape=(), dtype=float32)
# Start of epoch 16
# step 0: mean loss = tf.Tensor(22.215706, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(22.209255, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(22.204514, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(22.200285, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(22.195639, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(22.19035, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(22.185535, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(22.18036, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(22.17659, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(22.17014, shape=(), dtype=float32)
# Start of epoch 17
# step 0: mean loss = tf.Tensor(22.16802, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(22.162285, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(22.157776, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(22.15373, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(22.14944, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(22.144503, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(22.140095, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(22.134907, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(22.131758, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(22.125927, shape=(), dtype=float32)
# Start of epoch 18
# step 0: mean loss = tf.Tensor(22.123758, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(22.118498, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(22.113825, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(22.110346, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(22.106297, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(22.102268, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(22.097908, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(22.093294, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(22.09045, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(22.084917, shape=(), dtype=float32)
# Start of epoch 19
# step 0: mean loss = tf.Tensor(22.082813, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(22.077614, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(22.073868, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(22.070625, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(22.066746, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(22.06265, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(22.058962, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(22.05414, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(22.05129, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(22.046192, shape=(), dtype=float32)
# Start of epoch 20
# step 0: mean loss = tf.Tensor(22.044304, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(22.03961, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(22.035952, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(22.033012, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(22.02933, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(22.025545, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(22.02195, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(22.017717, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(22.015196, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(22.010296, shape=(), dtype=float32)
# Start of epoch 21
# step 0: mean loss = tf.Tensor(22.008453, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(22.003893, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(22.000566, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(21.997704, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(21.994352, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(21.990606, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(21.987503, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(21.98359, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(21.981026, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(21.976458, shape=(), dtype=float32)
# Start of epoch 22
# step 0: mean loss = tf.Tensor(21.974854, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(21.970497, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(21.967325, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(21.964499, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(21.961264, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(21.958118, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(21.95488, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(21.9511, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(21.94879, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(21.944366, shape=(), dtype=float32)
# Start of epoch 23
# step 0: mean loss = tf.Tensor(21.942915, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(21.939053, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(21.93588, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(21.933537, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(21.930412, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(21.927362, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(21.924374, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(21.920734, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(21.918726, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(21.914516, shape=(), dtype=float32)
# Start of epoch 24
# step 0: mean loss = tf.Tensor(21.913153, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(21.909182, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(21.906248, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(21.904161, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(21.901201, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(21.898281, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(21.89537, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(21.891977, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(21.889929, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(21.885971, shape=(), dtype=float32)
# Start of epoch 25
# step 0: mean loss = tf.Tensor(21.884665, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(21.881033, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(21.878305, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(21.876305, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(21.87339, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(21.870554, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(21.86775, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(21.864565, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(21.862894, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(21.85912, shape=(), dtype=float32)
# Start of epoch 26
# step 0: mean loss = tf.Tensor(21.857704, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(21.854225, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(21.85181, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(21.849493, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(21.847128, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(21.844284, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(21.841713, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(21.83857, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(21.83695, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(21.833258, shape=(), dtype=float32)
# Start of epoch 27
# step 0: mean loss = tf.Tensor(21.83199, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(21.828686, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(21.82627, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(21.82417, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(21.821695, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(21.81918, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(21.816795, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(21.813751, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(21.812164, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(21.808603, shape=(), dtype=float32)
# Start of epoch 28
# step 0: mean loss = tf.Tensor(21.807358, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(21.804235, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(21.80184, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(21.799965, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(21.797874, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(21.795437, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(21.792894, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(21.79028, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(21.788738, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(21.785442, shape=(), dtype=float32)
# Start of epoch 29
# step 0: mean loss = tf.Tensor(21.784197, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(21.781202, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(21.778872, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(21.777014, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(21.774906, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(21.772425, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(21.770159, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(21.76736, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(21.765783, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(21.762745, shape=(), dtype=float32)
# Start of epoch 30
# step 0: mean loss = tf.Tensor(21.761614, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(21.758747, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(21.756363, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(21.75459, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(21.752544, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(21.75017, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(21.747925, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(21.745327, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(21.744104, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(21.741055, shape=(), dtype=float32)
# Start of epoch 31
# step 0: mean loss = tf.Tensor(21.73989, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(21.737146, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(21.73499, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(21.733406, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(21.731264, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(21.729225, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(21.727385, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(21.724691, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(21.72332, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(21.720448, shape=(), dtype=float32)
# Start of epoch 32
# step 0: mean loss = tf.Tensor(21.719355, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(21.716637, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(21.714525, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(21.713045, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(21.711107, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(21.70892, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(21.706945, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(21.70468, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(21.703224, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(21.700716, shape=(), dtype=float32)
# Start of epoch 33
# step 0: mean loss = tf.Tensor(21.699533, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(21.696917, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(21.695086, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(21.69337, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(21.691599, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(21.689615, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(21.687849, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(21.685371, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(21.683977, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(21.681446, shape=(), dtype=float32)
# Start of epoch 34
# step 0: mean loss = tf.Tensor(21.680485, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(21.677923, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(21.675932, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(21.674397, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(21.672619, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(21.670736, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(21.66887, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(21.666584, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(21.665388, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(21.66267, shape=(), dtype=float32)
# Start of epoch 35
# step 0: mean loss = tf.Tensor(21.661886, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(21.659435, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(21.65772, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(21.656227, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(21.654608, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(21.652775, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(21.650972, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(21.648771, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(21.647738, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(21.64519, shape=(), dtype=float32)
# Start of epoch 36
# step 0: mean loss = tf.Tensor(21.644264, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(21.642033, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(21.640251, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(21.638638, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(21.63718, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(21.635536, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(21.633554, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(21.631428, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(21.630411, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(21.627949, shape=(), dtype=float32)
# Start of epoch 37
# step 0: mean loss = tf.Tensor(21.627134, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(21.624813, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(21.622978, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(21.621632, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(21.620123, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(21.618513, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(21.616735, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(21.614653, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(21.613531, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(21.611181, shape=(), dtype=float32)
# Start of epoch 38
# step 0: mean loss = tf.Tensor(21.610313, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(21.608187, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(21.606464, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(21.605318, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(21.603575, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(21.602098, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(21.600391, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(21.598467, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(21.597433, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(21.595201, shape=(), dtype=float32)
# Start of epoch 39
# step 0: mean loss = tf.Tensor(21.594217, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(21.591984, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(21.590414, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(21.588999, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(21.58749, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(21.58613, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(21.584408, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(21.582464, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(21.581326, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(21.579306, shape=(), dtype=float32)
# Start of epoch 40
# step 0: mean loss = tf.Tensor(21.578379, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(21.576374, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(21.574741, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(21.573542, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(21.572012, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(21.570482, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(21.568977, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(21.567154, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(21.566141, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(21.564016, shape=(), dtype=float32)
# Start of epoch 41
# step 0: mean loss = tf.Tensor(21.563282, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(21.561222, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(21.55968, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(21.558598, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(21.557072, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(21.555513, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(21.554155, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(21.552326, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(21.551311, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(21.549328, shape=(), dtype=float32)
# Start of epoch 42
# step 0: mean loss = tf.Tensor(21.54847, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(21.546488, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(21.544882, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(21.543894, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(21.54254, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(21.541092, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(21.53962, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(21.5377, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(21.536894, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(21.534866, shape=(), dtype=float32)
# Start of epoch 43
# step 0: mean loss = tf.Tensor(21.53405, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(21.532097, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(21.530815, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(21.529613, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(21.528248, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(21.526876, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(21.525547, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(21.523901, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(21.52294, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(21.520952, shape=(), dtype=float32)
# Start of epoch 44
# step 0: mean loss = tf.Tensor(21.5202, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(21.51835, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(21.517004, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(21.515894, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(21.51462, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(21.513205, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(21.511871, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(21.510277, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(21.509365, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(21.507473, shape=(), dtype=float32)
# Start of epoch 45
# step 0: mean loss = tf.Tensor(21.506683, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(21.504889, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(21.503414, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(21.502476, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(21.501183, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(21.499746, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(21.49841, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(21.496803, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(21.495935, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(21.493963, shape=(), dtype=float32)
# Start of epoch 46
# step 0: mean loss = tf.Tensor(21.493334, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(21.491556, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(21.490238, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(21.489094, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(21.488022, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(21.486755, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(21.485325, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(21.483725, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(21.48289, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(21.481066, shape=(), dtype=float32)
# Start of epoch 47
# step 0: mean loss = tf.Tensor(21.480381, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(21.478647, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(21.477463, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(21.476366, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(21.475069, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(21.473808, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(21.47246, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(21.470987, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(21.470177, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(21.4684, shape=(), dtype=float32)
# Start of epoch 48
# step 0: mean loss = tf.Tensor(21.467674, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(21.465998, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(21.464687, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(21.463633, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(21.462542, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(21.461317, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(21.460064, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(21.458448, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(21.457771, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(21.455952, shape=(), dtype=float32)
# Start of epoch 49
# step 0: mean loss = tf.Tensor(21.455286, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(21.4536, shape=(), dtype=float32)
# step 200: mean loss = tf.Tensor(21.45241, shape=(), dtype=float32)
# step 300: mean loss = tf.Tensor(21.451468, shape=(), dtype=float32)
# step 400: mean loss = tf.Tensor(21.45027, shape=(), dtype=float32)
# step 500: mean loss = tf.Tensor(21.44908, shape=(), dtype=float32)
# step 600: mean loss = tf.Tensor(21.447819, shape=(), dtype=float32)
# step 700: mean loss = tf.Tensor(21.446293, shape=(), dtype=float32)
# step 800: mean loss = tf.Tensor(21.445688, shape=(), dtype=float32)
# step 900: mean loss = tf.Tensor(21.443886, shape=(), dtype=float32)
# WARNING:absl:Found untraced functions such as dense_5_layer_call_fn, dense_5_layer_call_and_return_conditional_losses, dense_6_layer_call_fn, dense_6_layer_call_and_return_conditional_losses, dense_7_layer_call_fn while saving (showing 5 of 30). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: vae/assets
# INFO:tensorflow:Assets written to: vae/assets

# %%
import matplotlib.pyplot as plt

z_test, z_log_var, z = vae.encoder(x_test)
plt.figure(figsize=(6, 6))
plt.scatter(z_test[:, 0], z_test[:, 1], c=y_test,
            alpha=.4, s=3**2, cmap='viridis')
plt.colorbar()
plt.show()
